# %%
from tkinter import *
from tkinter.ttk import *

window = Tk()
window.title("Quiz Maker")
window.geometry("600x600")

q1_var = IntVar()
q2_var = IntVar()
q3_var = IntVar()
q4_var = IntVar()

#Question 1

lbl1 = Label(window, text = '1.Which is the capital of France?',font = ("Arial",12))
lbl1.place(x=10, y=10)

rad1 = Radiobutton(window,text='Berlin', value=1, variable=q1_var)
rad2 = Radiobutton(window,text='Mandrid', value=2, variable=q1_var)
rad3 = Radiobutton(window,text='Paris', value=3, variable=q1_var)
rad4 = Radiobutton(window,text='Rom', value=4, variable=q1_var)

rad1.place(x=10, y=30)
rad2.place(x=10, y=50)
rad3.place(x=10, y=70)
rad4.place(x=10, y=90)

#Question 2

lbl2 = Label(window, text = '2.Which is the largest mammal on earth?',font = ("Arial",12))
lbl2.place(x=10, y=120)

rad5 = Radiobutton(window,text='Afican elephant', value=1, variable=q2_var)
rad6 = Radiobutton(window,text='Blue Whale', value=2, variable=q2_var)
rad7 = Radiobutton(window,text='Giraff', value=3, variable=q2_var)
rad8 = Radiobutton(window,text='Great White Shark', value=4, variable=q2_var)

rad5.place(x=10, y=140)
rad6.place(x=10, y=160)
rad7.place(x=10, y=180)
rad8.place(x=10, y=200)

#Question 3

lbl3 = Label(window, text = '3.What is chemical symbol for water?',font = ("Arial",12))
lbl3.place(x=10, y=230)

rad9 = Radiobutton(window,text='Co2', value=1, variable=q3_var)
rad10 = Radiobutton(window,text='O2', value=2, variable=q3_var)
rad11 = Radiobutton(window,text='H2O', value=3, variable=q3_var)
rad12 = Radiobutton(window,text='NaCl', value=4, variable=q3_var)

rad9.place(x=10, y=250)
rad10.place(x=10, y=270)
rad11.place(x=10, y=290)
rad12.place(x=10, y=310)

#Question 4

lbl4 = Label(window, text = '''4.who wrote "Romeo and Juliet"?''',font = ("Arial",12))
lbl4.place(x=10, y=340)

rad13 = Radiobutton(window,text='Charles Dickens', value=1, variable=q4_var)
rad14 = Radiobutton(window,text='William Shakespear', value=2, variable=q4_var)
rad15 = Radiobutton(window,text='Mark Twain', value=3, variable=q4_var)
rad16 = Radiobutton(window,text='Jane Austen', value=4, variable=q4_var)

rad13.place(x=10, y=360)
rad14.place(x=10, y=380)
rad15.place(x=10, y=400)
rad16.place(x=10, y=420)

btn = Button(window, text = "Submit")
btn.place(x=50, y= 500)



window.mainloop()
